# %% [markdown]
# ## Aggregation in OOPS

# %%
class Customer:

    def __init__(self, name, gender, address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_info(self):
        print(f"Name: {self.name}, Gender: {self.gender},Address: {self.address.get_city()}, {self.address.pin}, {self.address.state}")

class Address:

    def __init__(self, city, pin, state):
        self.__city = city
        self.pin = pin
        self.state = state

    def get_city(self):
        return self.__city

# %% [markdown]
# ### Aggregation Diagram
#
# If you are getting this kind of diagram, that means you have to design the program that way. Helps to design the software.
#
# ![image.png](attachment:image.png)
